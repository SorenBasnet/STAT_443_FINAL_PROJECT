# %%
import shap 
import xgboost 
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as pyplot
import matplotlib

# %%
data = pd.read_csv("/Users/sorenbasnet/Documents/Github/STAT_443_FINAL_PROJECT/data/prediction_death_5_years/data_patient_file_cna_rai.txt", sep=r'\s+',index_col=0)
data.head()
# Out:
#           ONCOTREE_CODE DISEASE_TYPE  NORMAL_MEAN_COVERAGE  \
# SAMPLE_ID
# CRC_0001         CLLSLL          CLL                  63.0
# CRC_0002         CLLSLL          CLL                  70.1
# CRC_0003         CLLSLL          CLL                  77.2
# CRC_0004         CLLSLL          CLL                  60.2
# CRC_0005         CLLSLL          CLL                 106.5
#
#            TUMOR_MEAN_COVERAGE  TUMOR_SAMPLE_PURITY  TUMOR_SAMPLE_PLOIDY  \
# SAMPLE_ID
# CRC_0001                  79.7                 0.92                 2.00
# CRC_0002                 135.5                 0.94                 2.03
# CRC_0003                 141.1                 0.83                 2.05
# CRC_0004                 146.0                 0.92                 2.00
# CRC_0005                  82.1                 0.87                 2.05
#
#                          CANCER_TYPE  \
# SAMPLE_ID
# CRC_0001   Mature__B_Cell__Neoplasms
# CRC_0002   Mature__B_Cell__Neoplasms
# CRC_0003   Mature__B_Cell__Neoplasms
# CRC_0004   Mature__B_Cell__Neoplasms
# CRC_0005   Mature__B_Cell__Neoplasms
#
#                                         CANCER_TYPE_DETAILED SOMATIC_STATUS  \
# SAMPLE_ID
# CRC_0001   Chronic__Lymphocytic__Leukemia_Small__Lymphocy...        Matched
# CRC_0002   Chronic__Lymphocytic__Leukemia_Small__Lymphocy...        Matched
# CRC_0003   Chronic__Lymphocytic__Leukemia_Small__Lymphocy...        Matched
# CRC_0004   Chronic__Lymphocytic__Leukemia_Small__Lymphocy...        Matched
# CRC_0005   Chronic__Lymphocytic__Leukemia_Small__Lymphocy...        Matched
#
#           CLL_EPITYPE  ...  4p_status  6q_status  8p_status  8q_status  \
# SAMPLE_ID              ...
# CRC_0001        n_CLL  ...  Unchanged  Unchanged  Unchanged       Gain
# CRC_0002        n_CLL  ...  Unchanged  Unchanged  Unchanged  Unchanged
# CRC_0003        n_CLL  ...  Unchanged  Unchanged  Unchanged  Unchanged
# CRC_0004        m_CLL  ...  Unchanged  Unchanged  Unchanged  Unchanged
# CRC_0005        n_CLL  ...  Unchanged  Unchanged  Unchanged  Unchanged
#
#           tri12_status TREATMENT_STATUS_AT_SAMPLING RAI_AT_SAMPLING  \
# SAMPLE_ID
# CRC_0001     Unchanged                    Untreated             0.0
# CRC_0002     Unchanged                    Untreated             0.0
# CRC_0003          Gain                    Untreated             0.0
# CRC_0004     Unchanged                    Untreated             0.0
# CRC_0005          Gain                    Untreated             0.0
#
#           FIRST_TREATMENT_AFTER_SAMPLING surv_5yrs death_5yr
# SAMPLE_ID
# CRC_0001                    Chemo__+__Ab     60.00       0.0
# CRC_0002                    Chemo__+__Ab     60.00       0.0
# CRC_0003                    Chemo__+__Ab     51.25       1.0
# CRC_0004                    Chemo__+__Ab     60.00       0.0
# CRC_0005                    Chemo__+__Ab     60.00       0.0
#
# [5 rows x 54 columns]

# %%
data.columns
# Out:
# Index(['ONCOTREE_CODE', 'DISEASE_TYPE', 'NORMAL_MEAN_COVERAGE',
#        'TUMOR_MEAN_COVERAGE', 'TUMOR_SAMPLE_PURITY', 'TUMOR_SAMPLE_PLOIDY',
#        'CANCER_TYPE', 'CANCER_TYPE_DETAILED', 'SOMATIC_STATUS', 'CLL_EPITYPE',
#        'TUMOR_MOLECULAR_SUBTYPE', 'SEQUENCING_PLATFORM', 'RNA_SEQUENCING',
#        'RRBS', 'ARRAY450K', 'M.CLL_WES', 'U.CLL_WES', 'EC_DISCOVERY',
#        'EC_EXTENSION', 'IGLV3_21_R110', 'U1_STATUS', 'TMB_NONSYNONYMOUS',
#        'AGE', 'AGE_SAMPLING', 'SEX', 'OS_STATUS', 'OS_MONTHS', 'DEATH_DAYS',
#        'COHORT', 'IGHV_MUTATION_STATUS', 'IGHV_IDENTITY_PERCENTAGE',
#        'TREATMENT_STATUS', 'PRIOR_TREATMENT_CATEGORY',
#        'TREATMENT_AFTER_SAMPLING', 'EXPRESSION_CLUSTER', 'FFS_STATUS',
#        'FFS_MONTHS', '11q_status', '17p_status', '17q_status', '18p_status',
#        '19q_status', '20p_status', '2p_status', '4p_status', '6q_status',
#        '8p_status', '8q_status', 'tri12_status',
#        'TREATMENT_STATUS_AT_SAMPLING', 'RAI_AT_SAMPLING',
#        'FIRST_TREATMENT_AFTER_SAMPLING', 'surv_5yrs', 'death_5yr'],
#       dtype='str')

# %%
data = data.dropna(subset=["death_5yr"])

# %%
X = data.drop(columns=["death_5yr", "ONCOTREE_CODE", 
                       "DISEASE_TYPE", "CANCER_TYPE", "CANCER_TYPE_DETAILED", "SOMATIC_STATUS", 
                       "CLL_EPITYPE", "TUMOR_MOLECULAR_SUBTYPE", "SEQUENCING_PLATFORM", "RNA_SEQUENCING", 
                       "RRBS", "ARRAY450K", "M.CLL_WES", "U.CLL_WES", "EC_DISCOVERY", 
                       "EC_EXTENSION", "IGLV3_21_R110", "U1_STATUS", 
                       "AGE", "OS_STATUS", "OS_MONTHS", "DEATH_DAYS", "DEATH_DAYS", 
                       "EXPRESSION_CLUSTER", "FFS_STATUS", "FFS_MONTHS", "surv_5yrs"])
y = data["death_5yr"]

# %%
X = data.drop(columns=['ONCOTREE_CODE', 'DISEASE_TYPE', 'NORMAL_MEAN_COVERAGE',
       'TUMOR_MEAN_COVERAGE', 'TUMOR_SAMPLE_PURITY', 'TUMOR_SAMPLE_PLOIDY',
       'CANCER_TYPE', 'CANCER_TYPE_DETAILED', 'SOMATIC_STATUS', 'CLL_EPITYPE',
       'TUMOR_MOLECULAR_SUBTYPE', 'SEQUENCING_PLATFORM', 'RNA_SEQUENCING',
       'RRBS', 'ARRAY450K', 'M.CLL_WES', 'U.CLL_WES', 'EC_DISCOVERY',
       'EC_EXTENSION', 'IGLV3_21_R110', 'U1_STATUS', 'TMB_NONSYNONYMOUS',
       'AGE', 'AGE_SAMPLING', 'SEX', 'OS_STATUS', 'OS_MONTHS', 'DEATH_DAYS',
       'COHORT', 'IGHV_MUTATION_STATUS', 'IGHV_IDENTITY_PERCENTAGE',
       'TREATMENT_STATUS', 'PRIOR_TREATMENT_CATEGORY',
       'TREATMENT_AFTER_SAMPLING', 'EXPRESSION_CLUSTER', 'FFS_STATUS',
       'FFS_MONTHS', 
       'TREATMENT_STATUS_AT_SAMPLING', 'RAI_AT_SAMPLING',
       'FIRST_TREATMENT_AFTER_SAMPLING', 'surv_5yrs', 'death_5yr'])
y = data["death_5yr"]

# %%
# This automatically generated dummies for categorical data 
X = pd.get_dummies(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
y_train.isna().sum()
# Out:
# np.int64(0)

# %%
# train model 
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)

# %%
#2. Explain the model's predictions 
explainer = shap.Explainer(model)
shap_values = explainer(X_test)

#3.Visualize 
# This shows the distribution of impacts 
# for each feature 
shap.plots.beeswarm(shap_values[:,:,1])
# Out:
# .values =
# array([[[ 1.95428315e-03, -1.95428315e-03],
#         [ 1.65694369e-03, -1.65694369e-03],
#         [ 7.73136786e-03, -7.73136786e-03],
#         ...,
#         [ 1.79115186e-04, -1.79115186e-04],
#         [ 5.90330698e-03, -5.90330698e-03],
#         [ 3.66637689e-03, -3.66637689e-03]],
#
#        [[ 1.95428315e-03, -1.95428315e-03],
#         [ 1.65694369e-03, -1.65694369e-03],
#         [ 7.73136786e-03, -7.73136786e-03],
#         ...,
#         [ 1.79115186e-04, -1.79115186e-04],
#         [ 5.90330698e-03, -5.90330698e-03],
#         [ 3.66637689e-03, -3.66637689e-03]],
#
#        [[ 1.95428315e-03, -1.95428315e-03],
#         [ 1.65694369e-03, -1.65694369e-03],
#         [ 7.73136786e-03, -7.73136786e-03],
#         ...,
#         [ 1.79115186e-04, -1.79115186e-04],
#         [ 5.90330698e-03, -5.90330698e-03],
#         [ 3.66637689e-03, -3.66637689e-03]],
#
#        ...,
#
#        [[ 1.95428315e-03, -1.95428315e-03],
#         [ 1.65694369e-03, -1.65694369e-03],
#         [ 7.73136786e-03, -7.73136786e-03],
#         ...,
#         [ 1.79115186e-04, -1.79115186e-04],
#         [ 5.90330698e-03, -5.90330698e-03],
#         [ 3.66637689e-03, -3.66637689e-03]],
#
#        [[ 1.95428315e-03, -1.95428315e-03],
#         [ 1.65694369e-03, -1.65694369e-03],
#         [ 7.73136786e-03, -7.73136786e-03],
#         ...,
#         [ 1.79115186e-04, -1.79115186e-04],
#         [ 5.90330698e-03, -5.90330698e-03],
#         [ 3.66637689e-03, -3.66637689e-03]],
#
#        [[ 1.77987929e-03, -1.77987929e-03],
#         [ 2.40074204e-03, -2.40074204e-03],
#         [ 1.79589027e-02, -1.79589027e-02],
#         ...,
#         [ 3.64553287e-05, -3.64553287e-05],
#         [-2.73053954e-02,  2.73053954e-02],
#         [-3.16919794e-02,  3.16919794e-02]]], shape=(252, 24, 2))
#
# .base_values =
# array([[0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143],
#        [0.82892857, 0.17107143]])
#
# .data =
# array([[False,  True, False, ...,  True, False,  True],
#        [False,  True, False, ...,  True, False,  True],
#        [False,  True, False, ...,  True, False,  True],
#        ...,
#        [False,  True, False, ...,  True, False,  True],
#        [False,  True, False, ...,  True, False,  True],
#        [False,  True, False, ...,  True,  True, False]], shape=(252, 24))

# %%
# visualize the first tree in the forest plot 

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt 

plt.figure(figsize=(20,10), dpi=300)
plot_tree(model.estimators_[0], 
          feature_names=X.columns, 
          class_names=['Class_A', 'Class_B'], 
          filled=True)
plt.show()
